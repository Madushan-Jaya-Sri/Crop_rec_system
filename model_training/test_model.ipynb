# %%
import pandas as pd

df = pd.read_csv('/Users/jayasri/Documents/GitHub/Crop_rec_system/model_training/updated_crop_data.csv')

# %%
df
# Out:
#           N     P     K  temperature  humidity    ph  rainfall  label  \
# 0      71.0  54.0  16.0        22.61     63.69  5.75     86.97  Maize
# 1      61.0  44.0  17.0        26.10     71.57  6.93     13.36  Maize
# 2      80.0  43.0  16.0        23.56     71.59  6.66      8.90  Maize
# 3      73.0  58.0  21.0        19.97     57.68  6.60     83.11  Maize
# 4      61.0  38.0  20.0        18.48     62.70  5.97    174.51  Maize
# ...     ...   ...   ...          ...       ...   ...       ...    ...
# 2095  107.0  34.0  32.0        26.77     66.41  6.78     64.06    Tea
# 2096   99.0  15.0  27.0        27.42     56.64  6.09      8.70    Tea
# 2097  118.0  33.0  30.0        24.13     67.23  6.36     21.76    Tea
# 2098  117.0  32.0  34.0        26.27     52.13  6.76      2.76    Tea
# 2099  104.0  18.0  30.0        23.60     60.40  6.78     25.51    Tea
#
#       land_size  water_supply  preference_cereals  preference_vegetables  \
# ...

# %%
df['rainfall'].min()
# Out:
# np.float64(1.0)

# %%
df['rainfall'].max()
# Out:
# np.float64(199.92)
